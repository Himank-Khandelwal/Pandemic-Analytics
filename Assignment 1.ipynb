# %% [markdown]
# **String Excercise**

# %%
FirstName = 'Himank'
MiddleName = 'Yogesh'
LastName = 'Khandelwal'
FullName = FirstName+' '+MiddleName+' '+LastName
print(FullName)
# Out:
# Himank Yogesh Khandelwal

# %% [markdown]
# **In Session Excercise**

# %%
District = 'Gwalior'
InfectedTotalTillDate = 1234
InfectedOn10thJune2020 = 12
InfectedOn11thJune2020 = 2  
InfectedOn12thJune2020 = 13
PercChange = ((InfectedOn12thJune2020-InfectedOn10thJune2020)/InfectedOn12thJune2020)*100
print(str(PercChange)+'%')
# Out:
# 7.6923076923076925%
